# %%
import pandas as pd
import numpy as np
import pprint as pp
from collections import OrderedDict
import requests
import json
import datetime

# File to Load (Remember to Change These)
file_to_load = "db/schoolShootingData_withGeoCoordinates.csv"
schoolData = pd.read_csv(file_to_load, encoding="utf-8-sig")

# %%
schoolData.reset_index()
# Out:
#       index  Unnamed: 0        Date                                    School  \
# 0         0           0    1/5/1970                   Hine Junior High School
# 1         1           1    1/5/1970                         Sousa Junior High
# 2         2           2    1/5/1970                       Unnamed High School
# 3         3           3    2/6/1970               John F. Kennedy High School
# 4         4           4   3/23/1970            David Starr Jordan High School
# 5         5           5   4/15/1970            Pine Bluff Coleman High School
# 6         6           6   4/22/1970             Pierre S. du Pont High School
# 7         7           7    5/8/1970                        Carver High School
# 8         8           8   5/15/1970                    Ben Lomond High School
# 9         9           9   8/28/1970                     Riverside High School
# 10       10          10   8/31/1970               Allapatah Elementary School
# ...

# %%
schoolData['Date']= pd.to_datetime(schoolData['Date'])

# %%
schoolData= schoolData[(schoolData['Date']> datetime.date(2003,12,30))]
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
schoolData.head()
# Out:
#      Unnamed: 0       Date                          School        City State  \
# 749         749 2004-01-15              Pomona High School      Pomona    CA
# 750         750 2004-01-21  Fay Galloway Elementary School   Henderson    NV
# 751         751 2004-02-02       Ballou Senior High School  Washington    DC
# 752         752 2004-02-03        Youens Elementary School     Houston    TX
# 753         753 2004-02-06           Fair Park High School  Shreveport    LA
#
#      Reliability Score (1-5)  Killed  Wounded  Total Injured/Killed Victims  \
# 749                      2.0       0      1.0                             1
# 750                      2.0       2      0.0                             2
# 751                      2.0       1      1.0                             2
# 752                      2.0       0      1.0                             1
# 753                      2.0       0      0.0                             0
#
#     Gender of Victims (M/F/Both)  \
# ...

# %%
schoolData['Date']= pd.to_datetime(schoolData['Date']).map(lambda x: str(x.year)+"-" + str(x.month))

# %%
schoolData.head()
# Out:
#      Unnamed: 0    Date                          School        City State  \
# 749         749  2004-1              Pomona High School      Pomona    CA
# 750         750  2004-1  Fay Galloway Elementary School   Henderson    NV
# 751         751  2004-2       Ballou Senior High School  Washington    DC
# 752         752  2004-2        Youens Elementary School     Houston    TX
# 753         753  2004-2           Fair Park High School  Shreveport    LA
#
#      Reliability Score (1-5)  Killed  Wounded  Total Injured/Killed Victims  \
# 749                      2.0       0      1.0                             1
# 750                      2.0       2      0.0                             2
# 751                      2.0       1      1.0                             2
# 752                      2.0       0      1.0                             1
# 753                      2.0       0      0.0                             0
#
#     Gender of Victims (M/F/Both)  \
# ...

# %%
schoolData = schoolData.reset_index()

# %%
schooldataWithDate = schoolData[['Date','Killed']]

# %%
schooldataWithDate.head()
# Out:
#      Date  Killed
# 0  2004-1       0
# 1  2004-1       2
# 2  2004-2       1
# 3  2004-2       0
# 4  2004-2       0

# %%
schooldataWithDate.to_csv (r'db\schoolShootingAfter2004.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
